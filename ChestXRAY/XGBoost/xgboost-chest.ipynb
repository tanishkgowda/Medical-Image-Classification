# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

from xgboost import XGBClassifier
import xgboost as xgb

# %%
import os

for dirname, _, filenames in os.walk('/kaggle/input'):
    print(dirname)
# Out:
# /kaggle/input
# /kaggle/input/datasets
# /kaggle/input/datasets/paultimothymooney
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/chest_xray
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/chest_xray/val
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/chest_xray/val/PNEUMONIA
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/chest_xray/val/NORMAL
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/chest_xray/test
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/chest_xray/train
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/chest_xray/train/PNEUMONIA
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/chest_xray/train/NORMAL
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/__MACOSX
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/__MACOSX/chest_xray
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/__MACOSX/chest_xray/val
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/__MACOSX/chest_xray/val/PNEUMONIA
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/__MACOSX/chest_xray/val/NORMAL
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/__MACOSX/chest_xray/test
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/__MACOSX/chest_xray/test/NORMAL
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/__MACOSX/chest_xray/train
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/__MACOSX/chest_xray/train/PNEUMONIA
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/__MACOSX/chest_xray/train/NORMAL
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/val
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/val/PNEUMONIA
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/val/NORMAL
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/test
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/test/PNEUMONIA
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/test/NORMAL
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/train
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/train/PNEUMONIA
# /kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/train/NORMAL

# %%
base_dir = "/kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/"

train_pneumonia_dir = base_dir+'train/PNEUMONIA/'
train_normal_dir=base_dir+'train/NORMAL/'

test_pneumonia_dir = base_dir+'test/PNEUMONIA/'
test_normal_dir = base_dir+'test/NORMAL/'

val_normal_dir= base_dir+'val/NORMAL/'
val_pnrumonia_dir= base_dir+'val/PNEUMONIA/'

train_pn = [train_pneumonia_dir+"{}".format(i) for i in os.listdir(train_pneumonia_dir) ]
train_normal = [train_normal_dir+"{}".format(i) for i in os.listdir(train_normal_dir) ]

test_normal = [test_normal_dir+"{}".format(i) for i in os.listdir(test_normal_dir)]
test_pn = [test_pneumonia_dir+"{}".format(i) for i in os.listdir(test_pneumonia_dir)]

val_pn= [val_pnrumonia_dir+"{}".format(i) for i in os.listdir(val_pnrumonia_dir) ]
val_normal= [val_normal_dir+"{}".format(i) for i in os.listdir(val_normal_dir) ]

print ("Total images:",len(train_pn+train_normal+test_normal+test_pn+val_pn+val_normal))
print ("Total pneumonia images:",len(train_pn+test_pn+val_pn))
print ("Total Nomral images:",len(train_normal+test_normal+val_normal))
# Out:
# Total images: 5856
# Total pneumonia images: 4273
# Total Nomral images: 1583

# %%
# Dataset Splitting (train 80% , test 15% and validation 5% )
import random
# Gathering all pneumina and normal chest X-ray in two python list
pn = train_pn + test_pn + val_pn #4273
normal = train_normal + test_normal + val_normal #1583

random.seed(10)
random.shuffle(pn)
random.shuffle(normal)

# Spliting dataset in train set,test set and validation set.

train_imgs = pn[855:]+ normal[316:]  # 80% of 4273 Pneumonia and 1583 normal chest X-ray .
test_imgs = pn[:641]+ normal[:237]
val_imgs = pn[641:855] + normal[237:316]

random.seed(10)
random.shuffle(train_imgs)
random.shuffle(test_imgs)
random.shuffle(val_imgs)

print("Total Train Images %s containing %s pneumonia and %s normal images" 
      % (len(train_imgs),3418,1266))
print("Total Test Images %s containing %s pneumonia and %s normal images"
      % (len(test_imgs),641,237))
print("Total validation Images %s containing %s pneumonia and %s normal images" 
      % (len(val_imgs),214,79))
# Out:
# Total Train Images 4685 containing 3418 pneumonia and 1266 normal images
# Total Test Images 878 containing 641 pneumonia and 237 normal images
# Total validation Images 293 containing 214 pneumonia and 79 normal images

# %%
def preprocess_image(image_list):
    X = []
    y = []

    for image in image_list:

        try:
            img = cv2.imread(image, cv2.IMREAD_GRAYSCALE)

            img = cv2.resize(img, (128,128))

            img = img.astype(np.float32) / 255.0

            X.append(img)

        except:
            continue

        if 'NORMAL' in image:
            y.append(0)
        else:
            y.append(1)

    return np.array(X), np.array(y)

# %%
X_train, y_train = preprocess_image(train_imgs)
X_test, y_test = preprocess_image(test_imgs)
X_val, y_val = preprocess_image(val_imgs)

print(X_train.shape)
print(X_test.shape)
print(X_val.shape)
# Out:
# (4685, 128, 128)
# (878, 128, 128)
# (293, 128, 128)

# %%
#flattening 
X_train = X_train.reshape(X_train.shape[0], -1)

X_test = X_test.reshape(X_test.shape[0], -1)

X_val = X_val.reshape(X_val.shape[0], -1)

print(X_train.shape)
# Out:
# (4685, 16384)

# %%
xgb_params = {
    'objective': 'binary:logistic',  # Changed to binary objective
    'max_depth': 6,
    'learning_rate': 0.1,
    'n_estimators': 200,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'random_state': 42,
    'eval_metric': 'logloss',        # Changed to binary log loss
    'verbosity': 1
}

xgb_model = XGBClassifier(**xgb_params)

xgb_model.fit(
    X_train,
    y_train,
    eval_set=[(X_val, y_val)],
    verbose=True
)
# Out:
# [0]	validation_0-logloss:0.52658
# [1]	validation_0-logloss:0.48425
# [2]	validation_0-logloss:0.44822
# [3]	validation_0-logloss:0.42100
# [4]	validation_0-logloss:0.39162
# [5]	validation_0-logloss:0.36546
# [6]	validation_0-logloss:0.34673
# [7]	validation_0-logloss:0.32718
# [8]	validation_0-logloss:0.30837
# [9]	validation_0-logloss:0.29418
# [10]	validation_0-logloss:0.27983
# [11]	validation_0-logloss:0.26808
# [12]	validation_0-logloss:0.25584
# [13]	validation_0-logloss:0.24474
# [14]	validation_0-logloss:0.23579
# [15]	validation_0-logloss:0.22861
# [16]	validation_0-logloss:0.22039
# [17]	validation_0-logloss:0.21413
# [18]	validation_0-logloss:0.20815
# [19]	validation_0-logloss:0.20194
# [20]	validation_0-logloss:0.19723
# [21]	validation_0-logloss:0.19405
# [22]	validation_0-logloss:0.18850
# [23]	validation_0-logloss:0.18470
# [24]	validation_0-logloss:0.18033
# [25]	validation_0-logloss:0.17766
# [26]	validation_0-logloss:0.17497
# [27]	validation_0-logloss:0.16955
# [28]	validation_0-logloss:0.16571
# [29]	validation_0-logloss:0.16340
# [30]	validation_0-logloss:0.16178
# [31]	validation_0-logloss:0.15924
# [32]	validation_0-logloss:0.15558
# [33]	validation_0-logloss:0.15272
# [34]	validation_0-logloss:0.15183
# [35]	validation_0-logloss:0.14924
# [36]	validation_0-logloss:0.14605
# [37]	validation_0-logloss:0.14323
# [38]	validation_0-logloss:0.14121
# [39]	validation_0-logloss:0.14078
# [40]	validation_0-logloss:0.13768
# [41]	validation_0-logloss:0.13689
# [42]	validation_0-logloss:0.13637
# [43]	validation_0-logloss:0.13595
# [44]	validation_0-logloss:0.13485
# [45]	validation_0-logloss:0.13390
# [46]	validation_0-logloss:0.13427
# [47]	validation_0-logloss:0.13284
# [48]	validation_0-logloss:0.13255
# [49]	validation_0-logloss:0.13228
# [50]	validation_0-logloss:0.13035
# [51]	validation_0-logloss:0.12907
# [52]	validation_0-logloss:0.12826
# [53]	validation_0-logloss:0.12689
# [54]	validation_0-logloss:0.12582
# [55]	validation_0-logloss:0.12535
# [56]	validation_0-logloss:0.12360
# [57]	validation_0-logloss:0.12281
# [58]	validation_0-logloss:0.12124
# [59]	validation_0-logloss:0.12029
# [60]	validation_0-logloss:0.11944
# [61]	validation_0-logloss:0.11895
# [62]	validation_0-logloss:0.11881
# [63]	validation_0-logloss:0.11919
# [64]	validation_0-logloss:0.11900
# [65]	validation_0-logloss:0.11840
# [66]	validation_0-logloss:0.11857
# [67]	validation_0-logloss:0.11699
# [68]	validation_0-logloss:0.11605
# [69]	validation_0-logloss:0.11494
# [70]	validation_0-logloss:0.11574
# [71]	validation_0-logloss:0.11586
# [72]	validation_0-logloss:0.11582
# [73]	validation_0-logloss:0.11618
# [74]	validation_0-logloss:0.11582
# [75]	validation_0-logloss:0.11540
# [76]	validation_0-logloss:0.11511
# [77]	validation_0-logloss:0.11485
# [78]	validation_0-logloss:0.11525
# [79]	validation_0-logloss:0.11519
# [80]	validation_0-logloss:0.11414
# [81]	validation_0-logloss:0.11416
# [82]	validation_0-logloss:0.11486
# [83]	validation_0-logloss:0.11482
# [84]	validation_0-logloss:0.11484
# [85]	validation_0-logloss:0.11533
# [86]	validation_0-logloss:0.11582
# [87]	validation_0-logloss:0.11592
# [88]	validation_0-logloss:0.11522
# [89]	validation_0-logloss:0.11518
# [90]	validation_0-logloss:0.11488
# [91]	validation_0-logloss:0.11448
# [92]	validation_0-logloss:0.11442
# [93]	validation_0-logloss:0.11385
# [94]	validation_0-logloss:0.11420
# [95]	validation_0-logloss:0.11401
# [96]	validation_0-logloss:0.11408
# [97]	validation_0-logloss:0.11332
# [98]	validation_0-logloss:0.11324
# [99]	validation_0-logloss:0.11261
# [100]	validation_0-logloss:0.11237
# [101]	validation_0-logloss:0.11237
# [102]	validation_0-logloss:0.11216
# [103]	validation_0-logloss:0.11231
# [104]	validation_0-logloss:0.11231
# [105]	validation_0-logloss:0.11167
# [106]	validation_0-logloss:0.11182
# [107]	validation_0-logloss:0.11162
# [108]	validation_0-logloss:0.11213
# [109]	validation_0-logloss:0.11151
# [110]	validation_0-logloss:0.11130
# [111]	validation_0-logloss:0.11189
# [112]	validation_0-logloss:0.11167
# [113]	validation_0-logloss:0.11230
# [114]	validation_0-logloss:0.11178
# [115]	validation_0-logloss:0.11158
# [116]	validation_0-logloss:0.11207
# [117]	validation_0-logloss:0.11187
# [118]	validation_0-logloss:0.11190
# [119]	validation_0-logloss:0.11145
# [120]	validation_0-logloss:0.11135
# [121]	validation_0-logloss:0.11121
# [122]	validation_0-logloss:0.11085
# [123]	validation_0-logloss:0.11114
# [124]	validation_0-logloss:0.11110
# [125]	validation_0-logloss:0.11076
# [126]	validation_0-logloss:0.11062
# [127]	validation_0-logloss:0.11045
# [128]	validation_0-logloss:0.11028
# [129]	validation_0-logloss:0.11069
# [130]	validation_0-logloss:0.11030
# [131]	validation_0-logloss:0.11015
# [132]	validation_0-logloss:0.11054
# [133]	validation_0-logloss:0.11009
# [134]	validation_0-logloss:0.10988
# [135]	validation_0-logloss:0.11009
# [136]	validation_0-logloss:0.11030
# [137]	validation_0-logloss:0.11035
# [138]	validation_0-logloss:0.11050
# [139]	validation_0-logloss:0.11095
# [140]	validation_0-logloss:0.11108
# [141]	validation_0-logloss:0.11071
# [142]	validation_0-logloss:0.11077
# [143]	validation_0-logloss:0.11063
# [144]	validation_0-logloss:0.11089
# [145]	validation_0-logloss:0.11104
# [146]	validation_0-logloss:0.11062
# [147]	validation_0-logloss:0.11070
# [148]	validation_0-logloss:0.11053
# [149]	validation_0-logloss:0.11038
# [150]	validation_0-logloss:0.11046
# [151]	validation_0-logloss:0.11067
# [152]	validation_0-logloss:0.11054
# [153]	validation_0-logloss:0.11070
# [154]	validation_0-logloss:0.11072
# [155]	validation_0-logloss:0.11076
# [156]	validation_0-logloss:0.11041
# [157]	validation_0-logloss:0.11053
# [158]	validation_0-logloss:0.11062
# [159]	validation_0-logloss:0.11066
# [160]	validation_0-logloss:0.11088
# [161]	validation_0-logloss:0.11065
# [162]	validation_0-logloss:0.11076
# [163]	validation_0-logloss:0.11057
# [164]	validation_0-logloss:0.11051
# [165]	validation_0-logloss:0.11055
# [166]	validation_0-logloss:0.11031
# [167]	validation_0-logloss:0.11046
# [168]	validation_0-logloss:0.11003
# [169]	validation_0-logloss:0.11042
# [170]	validation_0-logloss:0.11038
# [171]	validation_0-logloss:0.11010
# [172]	validation_0-logloss:0.10998
# [173]	validation_0-logloss:0.11048
# [174]	validation_0-logloss:0.11008
# [175]	validation_0-logloss:0.11014
# [176]	validation_0-logloss:0.11006
# [177]	validation_0-logloss:0.11004
# [178]	validation_0-logloss:0.10997
# [179]	validation_0-logloss:0.10996
# [180]	validation_0-logloss:0.10981
# [181]	validation_0-logloss:0.10943
# [182]	validation_0-logloss:0.10908
# [183]	validation_0-logloss:0.10925
# [184]	validation_0-logloss:0.10896
# [185]	validation_0-logloss:0.10881
# [186]	validation_0-logloss:0.10930
# [187]	validation_0-logloss:0.10924
# [188]	validation_0-logloss:0.10888
# [189]	validation_0-logloss:0.10892
# [190]	validation_0-logloss:0.10900
# [191]	validation_0-logloss:0.10867
# [192]	validation_0-logloss:0.10853
# [193]	validation_0-logloss:0.10817
# [194]	validation_0-logloss:0.10858
# [195]	validation_0-logloss:0.10844
# [196]	validation_0-logloss:0.10861
# [197]	validation_0-logloss:0.10854
# [198]	validation_0-logloss:0.10855
# [199]	validation_0-logloss:0.10839
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y_pred = xgb_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# Training accuracy
y_train_pred = xgb_model.predict(X_train)
train_accuracy = accuracy_score(y_train, y_train_pred)

# Validation accuracy
y_val_pred = xgb_model.predict(X_val)
val_accuracy = accuracy_score(y_val, y_val_pred)

# Test accuracy
y_test_pred = xgb_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)

print(f"Training Accuracy   : {train_accuracy*100:.2f}%")
print(f"Validation Accuracy : {val_accuracy*100:.2f}%")
print(f"Test Accuracy       : {test_accuracy*100:.2f}%")
# Out:
# Training Accuracy   : 100.00%
# Validation Accuracy : 95.90%
# Test Accuracy       : 94.76%

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

print(classification_report(
    y_test,
    y_test_pred,
    target_names=['NORMAL', 'PNEUMONIA']
))

y_test_pred = xgb_model.predict(X_test)

cm = confusion_matrix(y_test, y_test_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=['NORMAL', 'PNEUMONIA']
)

disp.plot(cmap='Blues')
plt.title("XGBoost Confusion Matrix")
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.92      0.89      0.90       237
#    PNEUMONIA       0.96      0.97      0.96       641
#
#     accuracy                           0.95       878
#    macro avg       0.94      0.93      0.93       878
# weighted avg       0.95      0.95      0.95       878

# %%
# Get validation log loss history
results = xgb_model.evals_result()

val_logloss = results['validation_0']['logloss']

# Find best round and lowest log loss
best_round = np.argmin(val_logloss)
best_logloss = np.min(val_logloss)

print(f"Best Boosting Round : {best_round}")
print(f"Lowest Validation Log Loss : {best_logloss:.6f}")
# Out:
# Best Boosting Round : 193
# Lowest Validation Log Loss : 0.108168
